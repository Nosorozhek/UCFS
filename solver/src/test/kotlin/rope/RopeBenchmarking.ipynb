// %%
%useLatestDescriptors
%use kandy
%use dataframe

// %%
fun testString(n: Int) = generateSequence { "test".asSequence() }.flatten().take(n).joinToString("")

// %%
import org.jetbrains.kotlinx.kandy.letsplot.multiplot.context.PlotBunchBuffer
import rope.BenchmarkResult

fun PlotBunchBuffer.plotResults(
    results: DataFrame<BenchmarkResult>
) {
    add(results.plot {
        x("size") {
            axis.name = "Size of string"
        }
        y("meanTime") {
            axis.name = "Time, ms"
        }
        line {
            color("name")
            type = LineType.LONGDASH
        }
        points {
            size = 3.0
            symbol = Symbol.CIRCLE_OPEN
            color("name")
        }
        errorBars {
            yMin("minTime75")
            yMax("maxTime75")
            borderLine.type = LineType.DASHED
        }
    }, 0, 0, 600, 400)
    add(results.plot {
        x("size") {
            axis.name = "Size of string"
        }
        y("meanMemoryKb") {
            axis.name = "Memory, Kb"
        }
        line {
            color("name")
            type = LineType.LONGDASH
        }
        points {
            size = 3.0
            symbol = Symbol.CIRCLE_OPEN
            color("name")
        }
        errorBars {
            yMin("minMemoryKb75")
            yMax("maxMemoryKb75")
            borderLine.type = LineType.DASHED
        }
    }, 600, 0, 600, 400)
}

// %%
import rope.ConcatRopesBenchmark
import rope.ConcatStringsBenchmark

val concatResults: DataFrame<BenchmarkResult> = (listOf(1, 4, 7, 10).map { it * 100000 }.flatMap { i ->
    listOf(
        ConcatRopesBenchmark().run(50, 100, testString(i)),
        ConcatStringsBenchmark().run(50, 100, testString(i))
    )
}).toDataFrame()

// %%
plotBunch { plotResults(concatResults as DataFrame<BenchmarkResult>) }
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='1200' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;ENN8Kt&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;kind&quot;:&quot;ggbunch&quot;,
// &quot;items&quot;:[{
// &quot;x&quot;:0,
// &quot;width&quot;:600,
// &quot;y&quot;:0,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// ...

// %%
import rope.ConcatMultipleRopesBenchmark
import rope.ConcatMultipleStringsBenchmark

val concatMultipleResults: DataFrame<BenchmarkResult> = (listOf(1, 3, 6, 9).map { it * 1000 }.flatMap { i ->
    listOf(
        ConcatMultipleRopesBenchmark(100).run(50, 100, testString(i)),
        ConcatMultipleStringsBenchmark(100).run(50, 100, testString(i))
    )
}).toDataFrame()

// %%
plotBunch { plotResults(concatMultipleResults as DataFrame<BenchmarkResult>) }
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='1200' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;V6S0Um&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;kind&quot;:&quot;ggbunch&quot;,
// &quot;items&quot;:[{
// &quot;x&quot;:0,
// &quot;width&quot;:600,
// &quot;y&quot;:0,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// ...

// %%
import rope.SubRopeBenchmark
import rope.SubStringBenchmark

val subSequenceResults: DataFrame<BenchmarkResult> = (listOf(1, 3, 6, 9).map { it * 1000 }.flatMap { i ->
    listOf(
        SubRopeBenchmark(1000).run(50, 100, testString(i)),
        SubStringBenchmark(1000).run(50, 100, testString(i))
    )
}).toDataFrame()

// %%
plotBunch { plotResults(subSequenceResults as DataFrame<BenchmarkResult>) }
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='1200' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;ISocJk&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;kind&quot;:&quot;ggbunch&quot;,
// &quot;items&quot;:[{
// &quot;x&quot;:0,
// &quot;width&quot;:600,
// &quot;y&quot;:0,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// ...

// %%
import rope.IterateRopeBenchmark
import rope.IterateStringBenchmark

val iterateResults: DataFrame<BenchmarkResult> = (listOf(1, 3, 6, 9).map { it * 1000 }.flatMap { i ->
    listOf(
        IterateRopeBenchmark().run(50, 100, testString(i)),
        IterateStringBenchmark().run(50, 100, testString(i))
    )
}).toDataFrame()

// %%
plotBunch { plotResults(iterateResults as DataFrame<BenchmarkResult>) }
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='1200' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;FuBsL5&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;kind&quot;:&quot;ggbunch&quot;,
// &quot;items&quot;:[{
// &quot;x&quot;:0,
// &quot;width&quot;:600,
// &quot;y&quot;:0,
// &quot;feature_spec&quot;:{
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// ...
